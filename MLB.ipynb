# %% [markdown]
# <a href="https://colab.research.google.com/github/AshKate98/MLB-API-Introduction/blob/Ashkate98/MLB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

# %%
Jsonresponse = requests.get('http://statsapi.mlb.com/api/v1/schedule/games/?sportId=1')

# %%
Jsonresponse.status_code
# Out:
# 200

# %%
Jsonresponse.json()
# Out:
# {'copyright': 'Copyright 2021 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt',
#  'dates': [{'date': '2021-09-25',
#    'events': [],
#    'games': [{'calendarEventID': '14-632351-2021-09-25',
#      'content': {'link': '/api/v1/game/632351/content'},
#      'dayNight': 'day',
#      'doubleHeader': 'N',
#      'gameDate': '2021-09-25T18:20:00Z',
#      'gameNumber': 1,
#      'gamePk': 632351,
#      'gameType': 'R',
#      'gamedayType': 'P',
#      'gamesInSeries': 4,
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game',
#      'inningBreakLength': 120,
#      'isTie': False,
#      'link': '/api/v1.1/game/632351/feed/live',
#      'officialDate': '2021-09-25',
#      'publicFacing': True,
#      'recordSource': 'S',
#      'reverseHomeAwayStatus': False,
#      'scheduledInnings': 9,
#      'season': '2021',
#      'seasonDisplay': '2021',
# ...

# %%
Jsonresponse2 = requests.get('http://statsapi.mlb.com/api/v1/venues')

# %%
Jsonresponse2.status_code
# Out:
# 200

# %%
Jsonresponse2.json()
# Out:
# {'copyright': 'Copyright 2021 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt',
#  'venues': [{'active': True,
#    'id': 5515,
#    'link': '/api/v1/venues/5515',
#    'name': 'Colorado Convention Center'},
#   {'active': True,
#    'id': 5520,
#    'link': '/api/v1/venues/5520',
#    'name': 'FredNats Ballpark'},
#   {'active': True,
#    'id': 5525,
#    'link': '/api/v1/venues/5525',
#    'name': 'ABC Supply Stadium'},
#   {'active': False,
#    'id': 4009,
#    'link': '/api/v1/venues/4009',
#    'name': 'Miyagi Baseball Stadium'},
#   {'active': False,
#    'id': 4010,
#    'link': '/api/v1/venues/4010',
#    'name': 'Tsuruoka Dream Stadium'},
#   {'active': False,
#    'id': 4011,
#    'link': '/api/v1/venues/4011',
#    'name': 'Meiji Jingu Stadium'},
#   {'active': False,
#    'id': 3670,
#    'link': '/api/v1/venues/3670',
#    'name': 'Madonna Stadium'},
# ...

# %%
Jsonresponse3 = requests.get('http://statsapi.mlb.com/api/v1/schedule/games/?sportId=1&startDate=2021-09-25&endDate=2021-09-25')

# %%
Jsonresponse3.status_code
# Out:
# 200

# %%
Jsonresponse3.json()
# Out:
# {'copyright': 'Copyright 2021 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt',
#  'dates': [{'date': '2021-09-25',
#    'events': [],
#    'games': [{'calendarEventID': '14-632351-2021-09-25',
#      'content': {'link': '/api/v1/game/632351/content'},
#      'dayNight': 'day',
#      'doubleHeader': 'N',
#      'gameDate': '2021-09-25T18:20:00Z',
#      'gameNumber': 1,
#      'gamePk': 632351,
#      'gameType': 'R',
#      'gamedayType': 'P',
#      'gamesInSeries': 4,
#      'ifNecessary': 'N',
#      'ifNecessaryDescription': 'Normal Game',
#      'inningBreakLength': 120,
#      'isTie': False,
#      'link': '/api/v1.1/game/632351/feed/live',
#      'officialDate': '2021-09-25',
#      'publicFacing': True,
#      'recordSource': 'S',
#      'reverseHomeAwayStatus': False,
#      'scheduledInnings': 9,
#      'season': '2021',
#      'seasonDisplay': '2021',
# ...

# %%
Jsonresponse = Jsonresponse2.json()
Jsonresponsevenues = Jsonresponse['venues']
JsonresponsevenuesDf = pd.DataFrame(Jsonresponsevenues)
JsonSimple = pd.DataFrame(Jsonresponse['venues'])
